# %%
import logging
import os
import tornado.web as tw
import tornado.ioloop as ti

from dbc_pyutils import JSONFormatter
from dbc_pyutils import build_info
from dbc_pyutils import create_instance_id
from dbc_pyutils import Statistics
from dbc_pyutils import Stat
from dbc_pyutils import BaseHandler
from dbc_pyutils import StatusHandler
from dbc_pyutils import StaticHandler
from dbc_pyutils import create_post_examples_from_dir
from dbc_data import lowell_mapping_functions as lmf
from dataclasses import dataclass
from dataclasses import field
from typing import Type
from typing import Dict
from typing import List
import json5

# %%
@dataclass
class Work:
    workid: str
    can_be_read_independently: bool
    universe: Type["Universe"]
    series_memberships: dict = field(default_factory=dict) # dict from str (Series) -> list[int]

@dataclass
class Series:
    series_title: str
    series_description: str
    number_in_universe: int
    universe: Type["Universe"]
    included_works: set = field(default_factory=set) # set of WorkIds
    series_alternative_title: list = field(default_factory=list) # list of strings

@dataclass
class Universe:
    universe_title: str
    universe_description: str
    universe_alternative_title: list = field(default_factory=list) # list of strings
    included_series: set = field(default_factory=set) # set of Series titles objects
    included_works: set = field(default_factory=set) # set of WorkIds

# %%
def read_json_file(path, filename, input_works_dict, input_series_dict, input_universe_dict):
    works_dict: dict = input_works_dict
    series_dict: dict = input_series_dict
    universe_dict: dict = input_universe_dict
    with open(os.path.join(path, filename)) as fp:
        obj_list = json5.load(fp)
        for obj in obj_list:
            if "universeTitle" in obj and not obj["universeTitle"] in universe_dict:
                universe_description = obj.get("universeDescription", None)
                universe_alternative_title_str = obj.get("universeAlternativeTitle", None)
                universe_alternative_title = universe_alternative_title_str if universe_alternative_title_str else None
                universe = Universe(universe_title=obj["universeTitle"], universe_description=universe_description, universe_alternative_title=universe_alternative_title)
                universe_dict[obj["universeTitle"]] = universe
        for obj in obj_list:
            if "seriesTitle" in obj and not obj["seriesTitle"] in series_dict:
                series_descr = obj.get("seriesDescription", None)
                number_in_universe_str = obj.get("numberInUniverse", None)
                number_in_universe = int(number_in_universe_str) if number_in_universe_str  else None
                alternative_title_str = obj.get("seriesAlternativeTitle", None)
                series_alternative_title = alternative_title_str if alternative_title_str else None
                universe = universe_dict[obj["universeTitle"]] if "universeTitle" in obj else None
                series = Series(series_title=obj["seriesTitle"], series_description=series_descr, number_in_universe=number_in_universe, universe=universe, series_alternative_title=series_alternative_title)
                series_dict[obj["seriesTitle"]] = series
                universe = universe_dict.get(obj['universeTitle'], None) if 'universeTitle' in obj else None
                if universe:
                    universe.included_series.add(series.series_title)
        for obj in obj_list:
            if "workId" in obj:
                series = series_dict.get(obj["seriesTitle"], None) if "seriesTitle" in obj else None
                universe = universe_dict.get(obj['universeTitle'], None) if 'universeTitle' in obj else None
                number_in_series_str = obj.get("numberInSeries", None)
                number_in_series = [int(s) for s in number_in_series_str] if number_in_series_str else None
                if not obj["workId"] in works_dict: # this is a work we have not seen before
                    universe = universe_dict.get(obj["universeTitle"], None) if "universeTitle" in obj else None
                    can_be_read_independently = obj.get("canBeReadIndependently", False)
                    work = Work(workid=obj["workId"], series_memberships={series.series_title: number_in_series} if series else {}, can_be_read_independently=can_be_read_independently, universe=universe.universe_title if universe else None)
                    works_dict[obj["workId"]] = work
                else:
                    work = works_dict.get(obj["workId"])
                    if work:
                        series_memberships = work.series_memberships
                        if series_memberships and series:
                            series_memberships[series.series_title] = number_in_series
                if series:
                    series.included_works.add(work.workid)
                if universe:
                    universe.included_works.add(work.workid)
    return works_dict, series_dict, universe_dict

# %%
works_dict: dict = {}
series_dict: dict = {}
universe_dict: dict = {}
data_dir = '../data-files'
json_files = [json_file for json_file in os.listdir(data_dir) if json_file.endswith('.json')]
for jf in json_files:
    works_dict, series_dict, universe_dict = read_json_file(data_dir, jf, works_dict, series_dict, universe_dict)

# %%
works_dict
# Out:
# {'870970-basis:39014009': Work(workid='870970-basis:39014009', can_be_read_independently=False, universe=None, series_memberships={}),
#  '870970-basis:52623138': Work(workid='870970-basis:52623138', can_be_read_independently=False, universe=None, series_memberships={}),
#  '870970-basis:51998464': Work(workid='870970-basis:51998464', can_be_read_independently=False, universe=None, series_memberships={}),
#  '870970-basis:51026349': Work(workid='870970-basis:51026349', can_be_read_independently=False, universe=None, series_memberships={}),
#  '870970-basis:48960596': Work(workid='870970-basis:48960596', can_be_read_independently=False, universe=None, series_memberships={'De 5': [19]}),
#  '870970-basis:47917786': Work(workid='870970-basis:47917786', can_be_read_independently=False, universe=None, series_memberships={'De 5': [2]}),
#  '870970-basis:51663535': Work(workid='870970-basis:51663535', can_be_read_independently=False, universe=None, series_memberships={'De 5 (samling)': [6], 'De 5': [16, 17, 18]}),
#  '870970-basis:51077024': Work(workid='870970-basis:51077024', can_be_read_independently=False, universe=None, series_memberships={'De 5 (samling)': [4], 'De 5': [10, 11, 12]}),
#  '870970-basis:26070066': Work(workid='870970-basis:26070066', can_be_read_independently=False, universe=None, series_memberships={'De 5': [5]}),
#  '870970-basis:25891007': Work(workid='870970-basis:25891007', can_be_read_independently=False, universe=None, series_memberships={'De 5': [4]}),
#  '870970-basis:25650646': Work(workid='870970-basis:25650646', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Cirklen åbnes': [4]}),
#  '870970-basis:24950816': Work(workid='870970-basis:24950816', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Cirklen åbnes': [3]}),
#  '870970-basis:24930017': Work(workid='870970-basis:24930017', can_be_read_independently=False, universe='Tortall universet', series_memberships={'Løvindens sang': [1]}),
#  '870970-basis:24929957': Work(workid='870970-basis:24929957', can_be_read_independently=False, universe='Tortall universet', series_memberships={'Løvindens sang': [4]}),
#  '870970-basis:24929930': Work(workid='870970-basis:24929930', can_be_read_independently=False, universe='Tortall universet', series_memberships={'Løvindens sang': [3]}),
#  '870970-basis:24929906': Work(workid='870970-basis:24929906', can_be_read_independently=False, universe='Tortall universet', series_memberships={'Løvindens sang': [2]}),
#  '870970-basis:24370763': Work(workid='870970-basis:24370763', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Cirklen åbnes': [2]}),
#  '870970-basis:24272885': Work(workid='870970-basis:24272885', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Cirklen åbnes': [1]}),
#  '870970-basis:23423626': Work(workid='870970-basis:23423626', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Magiens cirkel': [4]}),
#  '870970-basis:22822896': Work(workid='870970-basis:22822896', can_be_read_independently=False, universe='Cirklen universet', series_memberships={'Magiens cirkel': [1]}),
#  '870970-basis:38666991': Work(workid='870970-basis:38666991', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [15]}),
#  '870970-basis:48857353': Work(workid='870970-basis:48857353', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [15]}),
#  '870970-basis:48739857': Work(workid='870970-basis:48739857', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Rowleys dagbog': [2]}),
#  '870970-basis:47575486': Work(workid='870970-basis:47575486', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [14]}),
#  '870970-basis:47241685': Work(workid='870970-basis:47241685', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [14]}),
#  '870970-basis:46960165': Work(workid='870970-basis:46960165', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Rowleys dagbog': [1]}),
#  '870970-basis:46107551': Work(workid='870970-basis:46107551', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [13]}),
#  '870970-basis:55112924': Work(workid='870970-basis:55112924', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [12]}),
#  '870970-basis:50618382': Work(workid='870970-basis:50618382', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [3]}),
#  '870970-basis:29570442': Work(workid='870970-basis:29570442', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [2]}),
#  '870970-basis:29570434': Work(workid='870970-basis:29570434', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [1]}),
#  '870970-basis:27443583': Work(workid='870970-basis:27443583', can_be_read_independently=False, universe='Wimpy Kid', series_memberships={'Wimpy Kid-serien': [1]}),
#  '870970-basis:44390132': Work(workid='870970-basis:44390132', can_be_read_independently=False, universe=None, series_memberships={'Wimpy Kid-serien': [2]}),
#  '870970-basis:44281589': Work(workid='870970-basis:44281589', can_be_read_independently=False, universe=None, series_memberships={'Wimpy Kid-serien': [1]}),
#  '870970-basis:47170648': Work(workid='870970-basis:47170648', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [2]}),
#  '870970-basis:46485319': Work(workid='870970-basis:46485319', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [6]}),
#  '870970-basis:51900731': Work(workid='870970-basis:51900731', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [1]}),
#  '870970-basis:50550877': Work(workid='870970-basis:50550877', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [3]}),
#  '870970-basis:27696279': Work(workid='870970-basis:27696279', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [4]}),
#  '870970-basis:27475868': Work(workid='870970-basis:27475868', can_be_read_independently=False, universe=None, series_memberships={'Aske i munden, sand i skoen': [5]}),
#  '870970-basis:53680151': Work(workid='870970-basis:53680151', can_be_read_independently=False, universe=None, series_memberships={'Asta': [12]}),
#  '870970-basis:52744040': Work(workid='870970-basis:52744040', can_be_read_independently=False, universe=None, series_memberships={'Asta': [11]}),
#  '870970-basis:52055377': Work(workid='870970-basis:52055377', can_be_read_independently=False, universe=None, series_memberships={'Asta': [10]}),
#  '870970-basis:28506449': Work(workid='870970-basis:28506449', can_be_read_independently=False, universe=None, series_memberships={'Asta': [2]}),
#  '870970-basis:28506392': Work(workid='870970-basis:28506392', can_be_read_independently=False, universe=None, series_memberships={'Asta': [1]}),
#  '870970-basis:47969301': Work(workid='870970-basis:47969301', can_be_read_independently=False, universe='Michael Connellys krimi-univers', series_memberships={'Renée Ballard-serien': [1]}),
#  '870970-basis:47969298': Work(workid='870970-basis:47969298', can_be_read_independently=False, universe='Michael Connellys krimi-univers', series_memberships={'Renée Ballard-serien': [2], 'Harry Bosch-serien': [21]}),
#  '870970-basis:47013615': Work(workid='870970-basis:47013615', can_be_read_independently=False, universe='Michael Connellys krimi-univers', series_memberships={'Renée Ballard series': [3], 'Harry Bosch series': [22]}),
#  '870970-basis:25330080': Work(workid='870970-basis:25330080', can_be_read_independently=False, universe='Michael Connellys krimi-univers', series_memberships={'Harry Bosch-serien': [1]}),
#  '870970-basis:38929496': Work(workid='870970-basis:38929496', can_be_read_independently=False, universe=None, series_memberships={'Den der lever stille': [2]}),
#  '870970-basis:38762311': Work(workid='870970-basis:38762311', can_be_read_independently=False, universe=None, series_memberships={'Den der lever stille': [2]}),
#  '870970-basis:54802196': Work(workid='870970-basis:54802196', can_be_read_independently=False, universe=None, series_memberships={'Den der lever stille': [1]}),
#  '870970-basis:53787452': Work(workid='870970-basis:53787452', can_be_read_independently=False, universe=None, series_memberships={'Den der lever stille': [1]}),
#  '870970-basis:53787444': Work(workid='870970-basis:53787444', can_be_read_independently=False, universe=None, series_memberships={'Den der lever stille': [1]}),
#  '870970-basis:06075126': Work(workid='870970-basis:06075126', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [3]}),
#  '870970-basis:06075118': Work(workid='870970-basis:06075118', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [3]}),
#  '870970-basis:05925355': Work(workid='870970-basis:05925355', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [2]}),
#  '870970-basis:05925347': Work(workid='870970-basis:05925347', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [2]}),
#  '870970-basis:05818745': Work(workid='870970-basis:05818745', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [1]}),
#  '870970-basis:05818729': Work(workid='870970-basis:05818729', can_be_read_independently=False, universe=None, series_memberships={'Hårdes saga': [1]}),
#  '870970-basis:39137348': Work(workid='870970-basis:39137348', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:38392271': Work(workid='870970-basis:38392271', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:38289977': Work(workid='870970-basis:38289977', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [1]}),
#  '870970-basis:48919901': Work(workid='870970-basis:48919901', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:48287484': Work(workid='870970-basis:48287484', can_be_read_independently=False, universe='Wizarding World', series_memberships={'The Harry Potter series': [1]}),
#  '870970-basis:47597137': Work(workid='870970-basis:47597137', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:47092183': Work(workid='870970-basis:47092183', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [4]}),
#  '870970-basis:47086868': Work(workid='870970-basis:47086868', can_be_read_independently=False, universe='Wizarding World', series_memberships={'The Harry Potter series': [4]}),
#  '870970-basis:46839293': Work(workid='870970-basis:46839293', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:46778243': Work(workid='870970-basis:46778243', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Fantastic beasts': None}),
#  '870970-basis:46777832': Work(workid='870970-basis:46777832', can_be_read_independently=False, universe='Wizarding World', series_memberships={}),
#  '870970-basis:46619501': Work(workid='870970-basis:46619501', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Fantastic beasts': None}),
#  '870970-basis:46429931': Work(workid='870970-basis:46429931', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Fantastic beasts': [2]}),
#  '870970-basis:46006631': Work(workid='870970-basis:46006631', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Fantastic beasts': [1]}),
#  '870970-basis:54872186': Work(workid='870970-basis:54872186', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [7]}),
#  '870970-basis:54872003': Work(workid='870970-basis:54872003', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [6]}),
#  '870970-basis:54871996': Work(workid='870970-basis:54871996', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [5]}),
#  '870970-basis:54871953': Work(workid='870970-basis:54871953', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [4]}),
#  '870970-basis:54871945': Work(workid='870970-basis:54871945', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [3]}),
#  '870970-basis:54871929': Work(workid='870970-basis:54871929', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter': [2]}),
#  '870970-basis:54871910': Work(workid='870970-basis:54871910', can_be_read_independently=False, universe='Wizarding World', series_memberships={'Harry Potter':
can_be_read_independently=False, universe='His dark materials', series_memberships={'His dark materials (Sæson 1)': [4, 5, 6]}),
#  '870970-basis:48036848': Work(workid='870970-basis:48036848', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas (tegneserie)': [3], 'His dark materials (tegneserie)': [1]}),
#  '870970-basis:47366941': Work(workid='870970-basis:47366941', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas (tegneserie)': [2], 'His dark materials (tegneserie)': [1]}),
#  '870970-basis:47363322': Work(workid='870970-basis:47363322', can_be_read_independently=False, universe='His dark materials', series_memberships={'Forestillinger om Støv': [1]}),
#  '870970-basis:47348293': Work(workid='870970-basis:47348293', can_be_read_independently=False, universe='His dark materials', series_memberships={'His dark materials (Sæson 1)': [1, 2, 3]}),
#  '870970-basis:47106036': Work(workid='870970-basis:47106036', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas (tegneserie)': [1], 'His dark materials (tegneserie)': [1]}),
#  '870970-basis:47007356': Work(workid='870970-basis:47007356', can_be_read_independently=False, universe='His dark materials', series_memberships={}),
#  '870970-basis:45919927': Work(workid='870970-basis:45919927', can_be_read_independently=False, universe='His dark materials', series_memberships={'The book of dust': [1]}),
#  '870970-basis:53464602': Work(workid='870970-basis:53464602', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas': [3]}),
#  '870970-basis:53464580': Work(workid='870970-basis:53464580', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas': [2]}),
#  '870970-basis:53464572': Work(workid='870970-basis:53464572', can_be_read_independently=False, universe='His dark materials', series_memberships={'Det gyldne kompas': [1]}),
#  '870970-basis:45703711': Work(workid='870970-basis:45703711', can_be_read_independently=False, universe='His dark materials', series_memberships={'His dark materials': [3]}),
#  '870970-basis:45660842': Work(workid='870970-basis:45660842', can_be_read_independently=False, universe='His dark materials', series_memberships={'His dark materials': [2]}),
#  '870970-basis:27068456': Work(workid='870970-basis:27068456', can_be_read_independently=False, universe='His dark materials', series_memberships={}),
#  '870970-basis:27060773': Work(workid='870970-basis:27060773', can_be_read_independently=False, universe='His dark materials', series_memberships={}),
#  '870970-basis:51663381': Work(workid='870970-basis:51663381', can_be_read_independently=False, universe='Inkal-sagaen', series_memberships={'Den sidste inkal': [3]}),
#  '870970-basis:29034419': Work(workid='870970-basis:29034419', can_be_read_independently=False, universe='Inkal-sagaen', series_memberships={'Den sidste inkal': [2]}),
#  '870970-basis:27982700': Work(workid='870970-basis:27982700', can_be_read_independently=False, universe='Jodoverset', series_memberships={}),
#  '870970-basis:27982654': Work(workid='870970-basis:27982654', can_be_read_independently=False, universe='Inkal-sagaen', series_memberships={'Den sidste inkal': [1]}),
#  '870970-basis:27563899': Work(workid='870970-basis:27563899', can_be_read_independently=False, universe='Inkal-sagaen', series_memberships={}),
#  '870970-basis:27505686': Work(workid='870970-basis:27505686', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene': [8]}),
#  '870970-basis:27425356': Work(workid='870970-basis:27425356', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Megalex': [3]}),
#  '870970-basis:27375766': Work(workid='870970-basis:27375766', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene': [7]}),
#  '870970-basis:27133592': Work(workid='870970-basis:27133592', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Metabaronernes kaste - Castaka': [1]}),
#  '870970-basis:26172063': Work(workid='870970-basis:26172063', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene': [6]}),
#  '870970-basis:25874161': Work(workid='870970-basis:25874161', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Metabaronernes kaste': [8]}),
#  '870970-basis:25376811': Work(workid='870970-basis:25376811', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene': [5]}),
#  '870970-basis:24853411': Work(workid='870970-basis:24853411', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene': [4]}),
#  '870970-basis:24575535': Work(workid='870970-basis:24575535', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Metabaronernes kaste': [0]}),
#  '870970-basis:24575519': Work(workid='870970-basis:24575519', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Metabaronernes kaste': [7]}),
#  '870970-basis:23911787': Work(workid='870970-basis:23911787', can_be_read_independently=False, universe='Jodoverset', series_memberships={'Teknofædrene':